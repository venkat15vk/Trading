# %% [markdown]
# # Project Details
# State notebook purpose here

# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

import datetime
# Load the tensorboard extension
# %reload_ext tensorboard

# Clear any logs from previous runs
# !rm -rf ./logs/ 


# Options for pandas
pd.options.display.max_columns = 500
pd.options.display.max_rows = 250

import yfinance as yf
import statistics

# %% [markdown]
# # Get Data
# Do work here

# %%
MarksymbolsDF = pd.read_csv('/Users/vk/Desktop/SchoolAndResearch/StockResearch/COMMON_CONFIG/FILTERED.csv')

MarkStocks = list(MarksymbolsDF['Symbol'])

#MarkStocks = ['ASTE','GRMN','HUM']


VKsymbolsDF = pd.read_csv('/Users/vk/Desktop/SchoolAndResearch/StockResearch/COMMON_CONFIG/FILTERED_VK.csv')
VKStocks = list(VKsymbolsDF['Symbol'])

# %%
for stock in MarkStocks:
    try:    
        ticker = yf.Ticker(stock)
        hist = ticker.history(period="45d")
        hist['TradeDate'] = hist.index
        hist = hist.sort_values('TradeDate', ascending=True)
        hist['Stock'] = stock

        
        
        
        
        dataDF = hist.filter(['Stock', 'TradeDate', 'Volume', 'Close'])
        dataDF = dataDF.sort_values('TradeDate', ascending=False)
        last5Days = dataDF.head(4)
        
        last5Days = last5Days.tail(3)
        last2Days = last5Days.head(2)
        
        todayPrice = float(last2Days['Close'][0])
        yesterdayPrice = float(last2Days['Close'][1])
        
        
#        if (todayPrice - yesterdayPrice) > 0:
            
        ax2 = dataDF.sort_values('TradeDate').plot(x='TradeDate', y='Close', color='Blue', kind='line', title=stock)
        dataDF = dataDF.head(10)
        ax = dataDF.sort_values('TradeDate').plot(x='TradeDate', y='Volume', color='Red', kind='bar', title=stock)
        plt.show(ax2)
    
        
    except:
        print ('Cannot get MARK stock quotes')

# %%
for stock in VKStocks:
    try:    
        ticker = yf.Ticker(stock)
        hist = ticker.history(period="10d")
        hist['TradeDate'] = hist.index
        hist = hist.sort_values('TradeDate', ascending=False)
        hist['Stock'] = stock

        
        
        ax2 = hist.sort_values('TradeDate').plot(x='TradeDate', y='Close', color='Blue', kind='line', title=stock)
        ax = hist.sort_values('TradeDate').plot(x='TradeDate', y='Volume', color='Red', kind='bar', title=stock)
        plt.show(ax2)
    
        
    except:
        print ('Cannot get VK stock quotes')
